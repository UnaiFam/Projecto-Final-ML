# %%
import pandas as pd
import os  
import numpy as np

# %%
os.chdir("../data")
df= pd.read_csv("quejas-clientes.csv", sep=",", )
df.drop(columns=["Unnamed: 0"], inplace=True)
df
# Out:
#        Complaint ID          Product                   Sub-product  \
# 0           1291006  Debt collection                           NaN
# 1           1290580  Debt collection                       Medical
# 2           1290564         Mortgage                  FHA mortgage
# 3           1291615      Credit card                           NaN
# 4           1292165  Debt collection      Non-federal student loan
# ...             ...              ...                           ...
# 28151       1178184  Debt collection                           NaN
# 28152       1178183    Consumer loan                  Vehicle loan
# 28153       1178182         Mortgage   Conventional fixed mortgage
# 28154       1178181      Payday loan                           NaN
# 28155       1178180  Money transfers  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX   76119.0    2015-03-19
# 1                       Debt is not mine    TX   77479.0    2015-03-19
# 2                                    NaN    MA    2127.0    2015-03-19
# 3                                    NaN    CA   92592.0    2015-03-19
# 4      Debt resulted from identity theft   NaN   43068.0    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX   75201.0    2015-01-01
# 28152                                NaN    GA   30043.0    2015-01-01
# 28153                                NaN    MN   55105.0    2015-01-01
# 28154                                NaN    CA   92509.0    2015-01-01
# 28155                                NaN    OH   45068.0    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-02        Enhanced Recovery Company, LLC
# 28152           2015-01-07                             DriveTime
# 28153           2015-01-02                               Regions
# 28154           2015-01-07                         Moneytree Inc
# 28155           2015-01-02                                PayPal
#
#                       Company response Timely response? Consumer disputed?
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
# [28156 rows x 13 columns]

# %%
us_states = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    'District of Columbia': "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY"
}

# %%
df["ZIP code"]=df["ZIP code"].astype("Int64")

# %%
df["Issue"].fillna("Unknown or not specified", inplace=True) 
df["Sub-issue"].fillna("Unknown or not specified", inplace=True)
df["Sub-product"].fillna("Unknown or not specified", inplace=True)
# Out:
# C:\Users\unaif\AppData\Local\Temp\ipykernel_22936\4195044070.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Issue"].fillna("Unknown or not specified", inplace=True)
# C:\Users\unaif\AppData\Local\Temp\ipykernel_22936\4195044070.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Sub-issue"].fillna("Unknown or not specified", inplace=True)
# C:\Users\unaif\AppData\Local\Temp\ipykernel_22936\4195044070.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Sub-product"].fillna("Unknown or not specified", inplace=True)

# %%
df
# Out:
#        Complaint ID          Product                   Sub-product  \
# 0           1291006  Debt collection      Unknown or not specified
# 1           1290580  Debt collection                       Medical
# 2           1290564         Mortgage                  FHA mortgage
# 3           1291615      Credit card      Unknown or not specified
# 4           1292165  Debt collection      Non-federal student loan
# ...             ...              ...                           ...
# 28151       1178184  Debt collection      Unknown or not specified
# 28152       1178183    Consumer loan                  Vehicle loan
# 28153       1178182         Mortgage   Conventional fixed mortgage
# 28154       1178181      Payday loan      Unknown or not specified
# 28155       1178180  Money transfers  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX     76119    2015-03-19
# 1                       Debt is not mine    TX     77479    2015-03-19
# 2               Unknown or not specified    MA      2127    2015-03-19
# 3               Unknown or not specified    CA     92592    2015-03-19
# 4      Debt resulted from identity theft   NaN     43068    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX     75201    2015-01-01
# 28152           Unknown or not specified    GA     30043    2015-01-01
# 28153           Unknown or not specified    MN     55105    2015-01-01
# 28154           Unknown or not specified    CA     92509    2015-01-01
# 28155           Unknown or not specified    OH     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-02        Enhanced Recovery Company, LLC
# 28152           2015-01-07                             DriveTime
# 28153           2015-01-02                               Regions
# 28154           2015-01-07                         Moneytree Inc
# 28155           2015-01-02                                PayPal
#
#                       Company response Timely response? Consumer disputed?
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
# [28156 rows x 13 columns]

# %%
import requests
def get_zip_info(zip_code):

    try:
        url = f"https://api.zippopotam.us/us/{int(zip_code)}"
        response = requests.get(url)
        if response.status_code == 200:
            return us_states[response.json()["places"][0]["state"]]
        else:
            return "Unknown"
    except Exception as e:
        return "Unknown"

# %%
get_zip_info(9)
# Out:
# 'Unknown'

# %%
get_zip_info(76119)
# Out:
# 'TX'

# %%
df[df["State"].isnull()]["ZIP code"]
# Out:
# 4        43068
# 393       <NA>
# 399      33027
# 410      32174
# 435      95476
#          ...
# 27782    85395
# 27865     <NA>
# 27881    37075
# 27919       11
# 27986     <NA>
# Name: ZIP code, Length: 421, dtype: Int64

# %%
df[df["State"].isnull()].index
# Out:
# Index([    4,   393,   399,   410,   435,   520,   543,   547,   624,   658,
#        ...
#        27268, 27355, 27400, 27486, 27498, 27782, 27865, 27881, 27919, 27986],
#       dtype='int64', length=421)

# %%
df["ZIP code"].fillna(0, inplace=True)
df
# Out:
# C:\Users\unaif\AppData\Local\Temp\ipykernel_22936\650062852.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ZIP code"].fillna(0, inplace=True)
#        Complaint ID          Product                   Sub-product  \
# 0           1291006  Debt collection      Unknown or not specified
# 1           1290580  Debt collection                       Medical
# 2           1290564         Mortgage                  FHA mortgage
# 3           1291615      Credit card      Unknown or not specified
# 4           1292165  Debt collection      Non-federal student loan
# ...             ...              ...                           ...
# 28151       1178184  Debt collection      Unknown or not specified
# 28152       1178183    Consumer loan                  Vehicle loan
# 28153       1178182         Mortgage   Conventional fixed mortgage
# 28154       1178181      Payday loan      Unknown or not specified
# 28155       1178180  Money transfers  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX     76119    2015-03-19
# 1                       Debt is not mine    TX     77479    2015-03-19
# 2               Unknown or not specified    MA      2127    2015-03-19
# 3               Unknown or not specified    CA     92592    2015-03-19
# 4      Debt resulted from identity theft   NaN     43068    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX     75201    2015-01-01
# 28152           Unknown or not specified    GA     30043    2015-01-01
# 28153           Unknown or not specified    MN     55105    2015-01-01
# 28154           Unknown or not specified    CA     92509    2015-01-01
# 28155           Unknown or not specified    OH     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-02        Enhanced Recovery Company, LLC
# 28152           2015-01-07                             DriveTime
# 28153           2015-01-02                               Regions
# 28154           2015-01-07                         Moneytree Inc
# 28155           2015-01-02                                PayPal
#
#                       Company response Timely response? Consumer disputed?
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
# [28156 rows x 13 columns]

# %%
null_state_rows = df[df["State"].isnull()]

for idx in null_state_rows.index:
    zip_code = df.loc[idx, "ZIP code"]
    state = get_zip_info(zip_code)
    df.loc[idx, "State"] = state

# %%
df
# Out:
#        Complaint ID          Product                   Sub-product  \
# 0           1291006  Debt collection      Unknown or not specified
# 1           1290580  Debt collection                       Medical
# 2           1290564         Mortgage                  FHA mortgage
# 3           1291615      Credit card      Unknown or not specified
# 4           1292165  Debt collection      Non-federal student loan
# ...             ...              ...                           ...
# 28151       1178184  Debt collection      Unknown or not specified
# 28152       1178183    Consumer loan                  Vehicle loan
# 28153       1178182         Mortgage   Conventional fixed mortgage
# 28154       1178181      Payday loan      Unknown or not specified
# 28155       1178180  Money transfers  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX     76119    2015-03-19
# 1                       Debt is not mine    TX     77479    2015-03-19
# 2               Unknown or not specified    MA      2127    2015-03-19
# 3               Unknown or not specified    CA     92592    2015-03-19
# 4      Debt resulted from identity theft    OH     43068    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX     75201    2015-01-01
# 28152           Unknown or not specified    GA     30043    2015-01-01
# 28153           Unknown or not specified    MN     55105    2015-01-01
# 28154           Unknown or not specified    CA     92509    2015-01-01
# 28155           Unknown or not specified    OH     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-02        Enhanced Recovery Company, LLC
# 28152           2015-01-07                             DriveTime
# 28153           2015-01-02                               Regions
# 28154           2015-01-07                         Moneytree Inc
# 28155           2015-01-02                                PayPal
#
#                       Company response Timely response? Consumer disputed?
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
# [28156 rows x 13 columns]

# %%
df[df["State"]!="Unknown"]
# Out:
#        Complaint ID          Product                   Sub-product  \
# 0           1291006  Debt collection      Unknown or not specified
# 1           1290580  Debt collection                       Medical
# 2           1290564         Mortgage                  FHA mortgage
# 3           1291615      Credit card      Unknown or not specified
# 4           1292165  Debt collection      Non-federal student loan
# ...             ...              ...                           ...
# 28151       1178184  Debt collection      Unknown or not specified
# 28152       1178183    Consumer loan                  Vehicle loan
# 28153       1178182         Mortgage   Conventional fixed mortgage
# 28154       1178181      Payday loan      Unknown or not specified
# 28155       1178180  Money transfers  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX     76119    2015-03-19
# 1                       Debt is not mine    TX     77479    2015-03-19
# 2               Unknown or not specified    MA      2127    2015-03-19
# 3               Unknown or not specified    CA     92592    2015-03-19
# 4      Debt resulted from identity theft    OH     43068    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX     75201    2015-01-01
# 28152           Unknown or not specified    GA     30043    2015-01-01
# 28153           Unknown or not specified    MN     55105    2015-01-01
# 28154           Unknown or not specified    CA     92509    2015-01-01
# 28155           Unknown or not specified    OH     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-02        Enhanced Recovery Company, LLC
# 28152           2015-01-07                             DriveTime
# 28153           2015-01-02                               Regions
# 28154           2015-01-07                         Moneytree Inc
# 28155           2015-01-02                                PayPal
#
#                       Company response Timely response? Consumer disputed?
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
# [27950 rows x 13 columns]

# %%
df["Date received"] = pd.to_datetime(df["Date received"], format="%Y-%m-%d")
df["Date received"]
# Out:
# 0       2015-03-19
# 1       2015-03-19
# 2       2015-03-19
# 3       2015-03-19
# 4       2015-03-19
#            ...
# 28151   2015-01-01
# 28152   2015-01-01
# 28153   2015-01-01
# 28154   2015-01-01
# 28155   2015-01-01
# Name: Date received, Length: 28156, dtype: datetime64[ns]

# %%
df["Date sent to company"] = pd.to_datetime(df["Date received"], format="%Y-%m-%d")
df["Date sent to company"]
# Out:
# 0       2015-03-19
# 1       2015-03-19
# 2       2015-03-19
# 3       2015-03-19
# 4       2015-03-19
#            ...
# 28151   2015-01-01
# 28152   2015-01-01
# 28153   2015-01-01
# 28154   2015-01-01
# 28155   2015-01-01
# Name: Date sent to company, Length: 28156, dtype: datetime64[ns]

# %%
df["dias de retraso"]=df["Date received"]-df["Date sent to company"]
df["dias de retraso"].value_counts()
# Out:
# dias de retraso
# 0 days    28156
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
product_encoder = LabelEncoder()

df['Product'] = product_encoder.fit_transform(df['Product'] )
df
# Out:
#        Complaint ID  Product                   Sub-product  \
# 0           1291006        4      Unknown or not specified
# 1           1290580        4                       Medical
# 2           1290564        6                  FHA mortgage
# 3           1291615        2      Unknown or not specified
# 4           1292165        4      Non-federal student loan
# ...             ...      ...                           ...
# 28151       1178184        4      Unknown or not specified
# 28152       1178183        1                  Vehicle loan
# 28153       1178182        6   Conventional fixed mortgage
# 28154       1178181        8      Unknown or not specified
# 28155       1178180        5  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX     76119    2015-03-19
# 1                       Debt is not mine    TX     77479    2015-03-19
# 2               Unknown or not specified    MA      2127    2015-03-19
# 3               Unknown or not specified    CA     92592    2015-03-19
# 4      Debt resulted from identity theft    OH     43068    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX     75201    2015-01-01
# 28152           Unknown or not specified    GA     30043    2015-01-01
# 28153           Unknown or not specified    MN     55105    2015-01-01
# 28154           Unknown or not specified    CA     92509    2015-01-01
# 28155           Unknown or not specified    OH     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-01        Enhanced Recovery Company, LLC
# 28152           2015-01-01                             DriveTime
# 28153           2015-01-01                               Regions
# 28154           2015-01-01                         Moneytree Inc
# 28155           2015-01-01                                PayPal
#
#                       Company response Timely response? Consumer disputed?  \
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
#       dias de retraso
# 0              0 days
# 1              0 days
# 2              0 days
# 3              0 days
# 4              0 days
# ...               ...
# 28151          0 days
# 28152          0 days
# 28153          0 days
# 28154          0 days
# 28155          0 days
#
# [28156 rows x 14 columns]

# %%
df['Sub-product']=df['Sub-product'].fillna("not specified")
df
# Out:
#        Complaint ID  Product                   Sub-product  \
# 0           1291006        4      Unknown or not specified
# 1           1290580        4                       Medical
# 2           1290564        6                  FHA mortgage
# 3           1291615        2      Unknown or not specified
# 4           1292165        4      Non-federal student loan
# ...             ...      ...                           ...
# 28151       1178184        4      Unknown or not specified
# 28152       1178183        1                  Vehicle loan
# 28153       1178182        6   Conventional fixed mortgage
# 28154       1178181        8      Unknown or not specified
# 28155       1178180        5  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX     76119    2015-03-19
# 1                       Debt is not mine    TX     77479    2015-03-19
# 2               Unknown or not specified    MA      2127    2015-03-19
# 3               Unknown or not specified    CA     92592    2015-03-19
# 4      Debt resulted from identity theft    OH     43068    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX     75201    2015-01-01
# 28152           Unknown or not specified    GA     30043    2015-01-01
# 28153           Unknown or not specified    MN     55105    2015-01-01
# 28154           Unknown or not specified    CA     92509    2015-01-01
# 28155           Unknown or not specified    OH     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-01        Enhanced Recovery Company, LLC
# 28152           2015-01-01                             DriveTime
# 28153           2015-01-01                               Regions
# 28154           2015-01-01                         Moneytree Inc
# 28155           2015-01-01                                PayPal
#
#                       Company response Timely response? Consumer disputed?  \
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
#       dias de retraso
# 0              0 days
# 1              0 days
# 2              0 days
# 3              0 days
# 4              0 days
# ...               ...
# 28151          0 days
# 28152          0 days
# 28153          0 days
# 28154          0 days
# 28155          0 days
#
# [28156 rows x 14 columns]

# %%
sub_product_encoder = LabelEncoder()
df['Sub-product']=df['Sub-product'].fillna("not specified")

df['Sub-product'] = sub_product_encoder.fit_transform(df['Sub-product'] )
df
# Out:
#        Complaint ID  Product  Sub-product  \
# 0           1291006        4           39
# 1           1290580        4           21
# 2           1290564        6           11
# 3           1291615        2           39
# 4           1292165        4           25
# ...             ...      ...          ...
# 28151       1178184        4           39
# 28152       1178183        1           42
# 28153       1178182        6            6
# 28154       1178181        8           39
# 28155       1178180        5           10
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue State  ZIP code Date received  \
# 0             Frequent or repeated calls    TX     76119    2015-03-19
# 1                       Debt is not mine    TX     77479    2015-03-19
# 2               Unknown or not specified    MA      2127    2015-03-19
# 3               Unknown or not specified    CA     92592    2015-03-19
# 4      Debt resulted from identity theft    OH     43068    2015-03-19
# ...                                  ...   ...       ...           ...
# 28151                   Debt is not mine    TX     75201    2015-01-01
# 28152           Unknown or not specified    GA     30043    2015-01-01
# 28153           Unknown or not specified    MN     55105    2015-01-01
# 28154           Unknown or not specified    CA     92509    2015-01-01
# 28155           Unknown or not specified    OH     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-01        Enhanced Recovery Company, LLC
# 28152           2015-01-01                             DriveTime
# 28153           2015-01-01                               Regions
# 28154           2015-01-01                         Moneytree Inc
# 28155           2015-01-01                                PayPal
#
#                       Company response Timely response? Consumer disputed?  \
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
#       dias de retraso
# 0              0 days
# 1              0 days
# 2              0 days
# 3              0 days
# 4              0 days
# ...               ...
# 28151          0 days
# 28152          0 days
# 28153          0 days
# 28154          0 days
# 28155          0 days
#
# [28156 rows x 14 columns]

# %%
State_enc = LabelEncoder()
"""df['State']=df['State'].fillna("not specified")"""

df['State'] = State_enc.fit_transform(df['State'] )
df
# Out:
#        Complaint ID  Product  Sub-product  \
# 0           1291006        4           39
# 1           1290580        4           21
# 2           1290564        6           11
# 3           1291615        2           39
# 4           1292165        4           25
# ...             ...      ...          ...
# 28151       1178184        4           39
# 28152       1178183        1           42
# 28153       1178182        6            6
# 28154       1178181        8           39
# 28155       1178180        5           10
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue  State  ZIP code Date received  \
# 0             Frequent or repeated calls     50     76119    2015-03-19
# 1                       Debt is not mine     50     77479    2015-03-19
# 2               Unknown or not specified     23      2127    2015-03-19
# 3               Unknown or not specified      7     92592    2015-03-19
# 4      Debt resulted from identity theft     40     43068    2015-03-19
# ...                                  ...    ...       ...           ...
# 28151                   Debt is not mine     50     75201    2015-01-01
# 28152           Unknown or not specified     13     30043    2015-01-01
# 28153           Unknown or not specified     28     55105    2015-01-01
# 28154           Unknown or not specified      7     92509    2015-01-01
# 28155           Unknown or not specified     40     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-01        Enhanced Recovery Company, LLC
# 28152           2015-01-01                             DriveTime
# 28153           2015-01-01                               Regions
# 28154           2015-01-01                         Moneytree Inc
# 28155           2015-01-01                                PayPal
#
#                       Company response Timely response? Consumer disputed?  \
# 0                          In progress              Yes                NaN
# 1              Closed with explanation              Yes                NaN
# 2              Closed with explanation              Yes                Yes
# 3                          In progress              Yes                NaN
# 4                          In progress              Yes                NaN
# ...                                ...              ...                ...
# 28151  Closed with non-monetary relief              Yes                 No
# 28152          Closed with explanation              Yes                NaN
# 28153  Closed with non-monetary relief              Yes                 No
# 28154          Closed with explanation              Yes                NaN
# 28155          Closed with explanation              Yes                Yes
#
#       dias de retraso
# 0              0 days
# 1              0 days
# 2              0 days
# 3              0 days
# 4              0 days
# ...               ...
# 28151          0 days
# 28152          0 days
# 28153          0 days
# 28154          0 days
# 28155          0 days
#
# [28156 rows x 14 columns]

# %%
Response_enc = LabelEncoder()
df['Company response'] = Response_enc.fit_transform(df['Company response'] )
df
# Out:
#        Complaint ID  Product  Sub-product  \
# 0           1291006        4           39
# 1           1290580        4           21
# 2           1290564        6           11
# 3           1291615        2           39
# 4           1292165        4           25
# ...             ...      ...          ...
# 28151       1178184        4           39
# 28152       1178183        1           42
# 28153       1178182        6            6
# 28154       1178181        8           39
# 28155       1178180        5           10
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue  State  ZIP code Date received  \
# 0             Frequent or repeated calls     50     76119    2015-03-19
# 1                       Debt is not mine     50     77479    2015-03-19
# 2               Unknown or not specified     23      2127    2015-03-19
# 3               Unknown or not specified      7     92592    2015-03-19
# 4      Debt resulted from identity theft     40     43068    2015-03-19
# ...                                  ...    ...       ...           ...
# 28151                   Debt is not mine     50     75201    2015-01-01
# 28152           Unknown or not specified     13     30043    2015-01-01
# 28153           Unknown or not specified     28     55105    2015-01-01
# 28154           Unknown or not specified      7     92509    2015-01-01
# 28155           Unknown or not specified     40     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-01        Enhanced Recovery Company, LLC
# 28152           2015-01-01                             DriveTime
# 28153           2015-01-01                               Regions
# 28154           2015-01-01                         Moneytree Inc
# 28155           2015-01-01                                PayPal
#
#        Company response Timely response? Consumer disputed? dias de retraso
# 0                     4              Yes                NaN          0 days
# 1                     1              Yes                NaN          0 days
# 2                     1              Yes                Yes          0 days
# 3                     4              Yes                NaN          0 days
# 4                     4              Yes                NaN          0 days
# ...                 ...              ...                ...             ...
# 28151                 3              Yes                 No          0 days
# 28152                 1              Yes                NaN          0 days
# 28153                 3              Yes                 No          0 days
# 28154                 1              Yes                NaN          0 days
# 28155                 1              Yes                Yes          0 days
#
# [28156 rows x 14 columns]

# %%
Time_enco = LabelEncoder()
df['Timely response?'] = Response_enc.fit_transform(df['Timely response?'] )

# %%
df
# Out:
#        Complaint ID  Product  Sub-product  \
# 0           1291006        4           39
# 1           1290580        4           21
# 2           1290564        6           11
# 3           1291615        2           39
# 4           1292165        4           25
# ...             ...      ...          ...
# 28151       1178184        4           39
# 28152       1178183        1           42
# 28153       1178182        6            6
# 28154       1178181        8           39
# 28155       1178180        5           10
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue  State  ZIP code Date received  \
# 0             Frequent or repeated calls     50     76119    2015-03-19
# 1                       Debt is not mine     50     77479    2015-03-19
# 2               Unknown or not specified     23      2127    2015-03-19
# 3               Unknown or not specified      7     92592    2015-03-19
# 4      Debt resulted from identity theft     40     43068    2015-03-19
# ...                                  ...    ...       ...           ...
# 28151                   Debt is not mine     50     75201    2015-01-01
# 28152           Unknown or not specified     13     30043    2015-01-01
# 28153           Unknown or not specified     28     55105    2015-01-01
# 28154           Unknown or not specified      7     92509    2015-01-01
# 28155           Unknown or not specified     40     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-01        Enhanced Recovery Company, LLC
# 28152           2015-01-01                             DriveTime
# 28153           2015-01-01                               Regions
# 28154           2015-01-01                         Moneytree Inc
# 28155           2015-01-01                                PayPal
#
#        Company response  Timely response? Consumer disputed? dias de retraso
# 0                     4                 1                NaN          0 days
# 1                     1                 1                NaN          0 days
# 2                     1                 1                Yes          0 days
# 3                     4                 1                NaN          0 days
# 4                     4                 1                NaN          0 days
# ...                 ...               ...                ...             ...
# 28151                 3                 1                 No          0 days
# 28152                 1                 1                NaN          0 days
# 28153                 3                 1                 No          0 days
# 28154                 1                 1                NaN          0 days
# 28155                 1                 1                Yes          0 days
#
# [28156 rows x 14 columns]

# %%
df["weekday"]=df["Date received"].dt.weekday

# %%
import holidays

# Verifica si una fecha en EE.UU. es festivo
us_holidays = holidays.US()
df["holiday"]= df["Date received"].isin(us_holidays)
df
# Out:
#        Complaint ID  Product  Sub-product  \
# 0           1291006        4           39
# 1           1290580        4           21
# 2           1290564        6           11
# 3           1291615        2           39
# 4           1292165        4           25
# ...             ...      ...          ...
# 28151       1178184        4           39
# 28152       1178183        1           42
# 28153       1178182        6            6
# 28154       1178181        8           39
# 28155       1178180        5           10
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue  State  ZIP code Date received  \
# 0             Frequent or repeated calls     50     76119    2015-03-19
# 1                       Debt is not mine     50     77479    2015-03-19
# 2               Unknown or not specified     23      2127    2015-03-19
# 3               Unknown or not specified      7     92592    2015-03-19
# 4      Debt resulted from identity theft     40     43068    2015-03-19
# ...                                  ...    ...       ...           ...
# 28151                   Debt is not mine     50     75201    2015-01-01
# 28152           Unknown or not specified     13     30043    2015-01-01
# 28153           Unknown or not specified     28     55105    2015-01-01
# 28154           Unknown or not specified      7     92509    2015-01-01
# 28155           Unknown or not specified     40     45068    2015-01-01
#
#       Date sent to company                               Company  \
# 0               2015-03-19           Premium Asset Services, LLC
# 1               2015-03-19  Accounts Receivable Consultants Inc.
# 2               2015-03-19                          RBS Citizens
# 3               2015-03-19                              Navy FCU
# 4               2015-03-19               Transworld Systems Inc.
# ...                    ...                                   ...
# 28151           2015-01-01        Enhanced Recovery Company, LLC
# 28152           2015-01-01                             DriveTime
# 28153           2015-01-01                               Regions
# 28154           2015-01-01                         Moneytree Inc
# 28155           2015-01-01                                PayPal
#
#        Company response  Timely response? Consumer disputed? dias de retraso  \
# 0                     4                 1                NaN          0 days
# 1                     1                 1                NaN          0 days
# 2                     1                 1                Yes          0 days
# 3                     4                 1                NaN          0 days
# 4                     4                 1                NaN          0 days
# ...                 ...               ...                ...             ...
# 28151                 3                 1                 No          0 days
# 28152                 1                 1                NaN          0 days
# 28153                 3                 1                 No          0 days
# 28154                 1                 1                NaN          0 days
# 28155                 1                 1                Yes          0 days
#
#        weekday  holiday
# 0            3    False
# 1            3    False
# 2            3    False
# 3            3    False
# 4            3    False
# ...        ...      ...
# 28151        3    False
# 28152        3    False
# 28153        3    False
# 28154        3    False
# 28155        3    False
#
# [28156 rows x 16 columns]

# %%
Company_enco = LabelEncoder()
df['Company'] = Company_enco.fit_transform(df['Company'] )

# %%
df
# Out:
#        Complaint ID  Product  Sub-product  \
# 0           1291006        4           39
# 1           1290580        4           21
# 2           1290564        6           11
# 3           1291615        2           39
# 4           1292165        4           25
# ...             ...      ...          ...
# 28151       1178184        4           39
# 28152       1178183        1           42
# 28153       1178182        6            6
# 28154       1178181        8           39
# 28155       1178180        5           10
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# 2      Application, originator, mortgage broker
# 3                                         Other
# 4         Cont'd attempts collect debt not owed
# ...                                         ...
# 28151     Cont'd attempts collect debt not owed
# 28152              Taking out the loan or lease
# 28153  Loan servicing, payments, escrow account
# 28154        Can't stop charges to bank account
# 28155                  Other transaction issues
#
#                                Sub-issue  State  ZIP code Date received  \
# 0             Frequent or repeated calls     50     76119    2015-03-19
# 1                       Debt is not mine     50     77479    2015-03-19
# 2               Unknown or not specified     23      2127    2015-03-19
# 3               Unknown or not specified      7     92592    2015-03-19
# 4      Debt resulted from identity theft     40     43068    2015-03-19
# ...                                  ...    ...       ...           ...
# 28151                   Debt is not mine     50     75201    2015-01-01
# 28152           Unknown or not specified     13     30043    2015-01-01
# 28153           Unknown or not specified     28     55105    2015-01-01
# 28154           Unknown or not specified      7     92509    2015-01-01
# 28155           Unknown or not specified     40     45068    2015-01-01
#
#       Date sent to company  Company  Company response  Timely response?  \
# 0               2015-03-19     1069                 4                 1
# 1               2015-03-19       50                 1                 1
# 2               2015-03-19     1118                 1                 1
# 3               2015-03-19      967                 4                 1
# 4               2015-03-19     1401                 4                 1
# ...                    ...      ...               ...               ...
# 28151           2015-01-01      489                 3                 1
# 28152           2015-01-01      459                 1                 1
# 28153           2015-01-01     1157                 3                 1
# 28154           2015-01-01      904                 1                 1
# 28155           2015-01-01     1038                 1                 1
#
#       Consumer disputed? dias de retraso  weekday  holiday
# 0                    NaN          0 days        3    False
# 1                    NaN          0 days        3    False
# 2                    Yes          0 days        3    False
# 3                    NaN          0 days        3    False
# 4                    NaN          0 days        3    False
# ...                  ...             ...      ...      ...
# 28151                 No          0 days        3    False
# 28152                NaN          0 days        3    False
# 28153                 No          0 days        3    False
# 28154                NaN          0 days        3    False
# 28155                Yes          0 days        3    False
#
# [28156 rows x 16 columns]

# %%
df["Consumer disputed?"].fillna("Unknown or not specified", inplace=True)
# Out:
# C:\Users\unaif\AppData\Local\Temp\ipykernel_22936\971246955.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Consumer disputed?"].fillna("Unknown or not specified", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28156 entries, 0 to 28155
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Complaint ID          28156 non-null  int64
#  1   Product               28156 non-null  int64
#  2   Sub-product           28156 non-null  int64
#  3   Issue                 28156 non-null  object
#  4   Sub-issue             28156 non-null  object
#  5   State                 28156 non-null  int64
#  6   ZIP code              28156 non-null  Int64
#  7   Date received         28156 non-null  datetime64[ns]
#  8   Date sent to company  28156 non-null  datetime64[ns]
#  9   Company               28156 non-null  int64
#  10  Company response      28156 non-null  int64
#  11  Timely response?      28156 non-null  int64
#  12  Consumer disputed?    28156 non-null  object
#  13  dias de retraso       28156 non-null  timedelta64[ns]
#  14  weekday               28156 non-null  int32
#  15  holiday               28156 non-null  bool
# dtypes: Int64(1), bool(1), datetime64[ns](2), int32(1), int64(7), object(3), timedelta64[ns](1)
# memory usage: 3.2+ MB

# %%
#df.to_csv("quejas-clientes-limpio.csv", index=False)
