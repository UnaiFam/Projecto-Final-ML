# %%
import os 
import pandas as pd
os.chdir("../data")
df= pd.read_csv("quejas-clientes.csv", sep=",", )
df.drop(columns=["Unnamed: 0"], inplace=True)
df
# Out:
#        Complaint ID          Product                   Sub-product  \
# 0           1291006  Debt collection                           NaN
# 1           1290580  Debt collection                       Medical
# 2           1290564         Mortgage                  FHA mortgage
# 3           1291615      Credit card                           NaN
# 4           1292165  Debt collection      Non-federal student loan
# ...             ...              ...                           ...
# 28151       1178184  Debt collection                           NaN
# 28152       1178183    Consumer loan                  Vehicle loan
# 28153       1178182         Mortgage   Conventional fixed mortgage
# 28154       1178181      Payday loan                           NaN
# 28155       1178180  Money transfers  Domestic (US) money transfer
#
#                                           Issue  \
# 0                         Communication tactics
# 1         Cont'd attempts collect debt not owed
# ...

# %%
os.chdir("../src")

# %%
from  tool_preprocess import preprocesing_function_paraforest

# %%
df.iloc[2]
# Out:
# Complaint ID                                             1290564
# Product                                                 Mortgage
# Sub-product                                         FHA mortgage
# Issue                   Application, originator, mortgage broker
# Sub-issue                                                    NaN
# State                                                         MA
# ZIP code                                                  2127.0
# Date received                                         2015-03-19
# Date sent to company                                  2015-03-19
# Company                                             RBS Citizens
# Company response                         Closed with explanation
# Timely response?                                             Yes
# Consumer disputed?                                           Yes
# Name: 2, dtype: object

# %%
from tool_preprocess import get_zip_info
get_zip_info(30043)
# Out:
# 'GA'

# %%
pd.DataFrame()

# %%
from tool_preprocess import product_decoder
product_decoder(0,1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 from tool_preprocess import product_decoder
# ----> 2 product_decoder(0,1,2,3,4)
#
# TypeError: product_decoder() takes 1 positional argument but 5 were given

# %%
df["ZIP code"]=df["ZIP code"].astype("Int64")
df["ZIP code"]
# Out:
# 0        76119
# 1        77479
# 2         2127
# 3        92592
# 4        43068
#          ...
# 28151    75201
# 28152    30043
# 28153    55105
# 28154    92509
# 28155    45068
# Name: ZIP code, Length: 28156, dtype: Int64

# %%
df.iloc[3:5]
# Out:
#    Complaint ID          Product               Sub-product  \
# 3       1291615      Credit card                       NaN
# 4       1292165  Debt collection  Non-federal student loan
#
#                                    Issue                          Sub-issue  \
# 3                                  Other                                NaN
# 4  Cont'd attempts collect debt not owed  Debt resulted from identity theft
#
#   State  ZIP code Date received Date sent to company                  Company  \
# 3    CA     92592    2015-03-19           2015-03-19                 Navy FCU
# 4   NaN     43068    2015-03-19           2015-03-19  Transworld Systems Inc.
#
#   Company response Timely response? Consumer disputed?
# 3      In progress              Yes                NaN
# 4      In progress              Yes                NaN

# %%
df["ZIP code"]
# Out:
# 0        76119
# 1        77479
# 2         2127
# 3        92592
# 4        43068
#          ...
# 28151    75201
# 28152    30043
# 28153    55105
# 28154    92509
# 28155    45068
# Name: ZIP code, Length: 28156, dtype: Int64

# %%
df1=preprocesing_function_paraforest(df[2:5])
# Out:
# c:\Users\unaif\OneDrive\Documentos\Documentos_Clase_Data\PROYECTOS\nombre_proyecto_final_ML\Projecto-Final-ML\src\tool_preprocess.py:239: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ZIP code"].fillna(000, inplace=True)
# c:\Users\unaif\OneDrive\Documentos\Documentos_Clase_Data\PROYECTOS\nombre_proyecto_final_ML\Projecto-Final-ML\src\tool_preprocess.py:242: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df1
# Out:
#    Complaint ID  Product  Sub-product  Issue  Sub-issue  State  ZIP code  \
# 2       1290564        6           11      7         45      1      2127
# 3       1291615        2           39     63         45      0     92592
# 4       1292165        4           25     24         12      2     43068
#
#   Date received Date sent to company                  Company  \
# 2    2015-03-19           2015-03-19             RBS Citizens
# 3    2015-03-19           2015-03-19                 Navy FCU
# 4    2015-03-19           2015-03-19  Transworld Systems Inc.
#
#    Company response  Timely response?  Consumer disputed?
# 2                 1                 1                   2
# 3                 4                 1                   1
# 4                 4                 1                   1
