# %%
import os
import pandas as pd
os.chdir("../src")
from tool_preprocess import State_enc, product_encoder, sub_Issue_enc, sub_product_encoder,  Issue_enc, Company_response_enc, Time_enco, preprocesing_function_paraforest

# %%
pd.DataFrame({"State":State_enc.classes_, "ID":State_enc.transform(State_enc.classes_), })
# Out:
#                        State  ID
# 0                         AE   0
# 1                         AK   1
# 2                         AL   2
# 3                         AP   3
# 4                         AR   4
# 5                         AS   5
# 6                         AZ   6
# 7                         CA   7
# 8                         CO   8
# 9                         CT   9
# 10                        DC  10
# 11                        DE  11
# 12                        FL  12
# 13                        GA  13
# 14                        GU  14
# 15                        HI  15
# 16                        IA  16
# 17                        ID  17
# 18                        IL  18
# 19                        IN  19
# 20                        KS  20
# 21                        KY  21
# 22                        LA  22
# 23                        MA  23
# 24                        MD  24
# 25                        ME  25
# 26                        MH  26
# 27                        MI  27
# 28                        MN  28
# 29                        MO  29
# 30                        MS  30
# 31                        MT  31
# 32                        NC  32
# 33                        ND  33
# 34                        NE  34
# 35                        NH  35
# 36                        NJ  36
# 37                        NM  37
# 38                        NV  38
# 39                        NY  39
# 40                        OH  40
# 41                        OK  41
# 42                        OR  42
# 43                        PA  43
# 44                        PR  44
# 45                        PW  45
# 46                        RI  46
# 47                        SC  47
# 48                        SD  48
# 49                        TN  49
# 50                        TX  50
# 51                        UT  51
# 52  Unknown or not specified  52
# 53                        VA  53
# 54                        VI  54
# 55                        VT  55
# 56                        WA  56
# 57                        WI  57
# 58                        WV  58
# 59                        WY  59

# %%
pd.DataFrame({"product":product_encoder.classes_, "ID":product_encoder.transform(product_encoder.classes_), })
# Out:
#                      product  ID
# 0    Bank account or service   0
# 1              Consumer loan   1
# 2                Credit card   2
# 3           Credit reporting   3
# 4            Debt collection   4
# 5            Money transfers   5
# 6                   Mortgage   6
# 7    Other financial service   7
# 8                Payday loan   8
# 9               Prepaid card   9
# 10              Student loan  10
# 11  Unknown or not specified  11

# %%
pd.DataFrame({"sub-product":sub_product_encoder.classes_, "ID":sub_product_encoder.transform(sub_product_encoder.classes_), })
# Out:
#                                sub-product  ID
# 0              (CD) Certificate of deposit   0
# 1                                     Auto   1
# 2       Cashing a check without an account   2
# 3                            Check cashing   3
# 4                         Checking account   4
# 5   Conventional adjustable mortgage (ARM)   5
# 6              Conventional fixed mortgage   6
# 7                              Credit card   7
# 8                            Credit repair   8
# 9                          Debt settlement   9
# 10            Domestic (US) money transfer  10
# 11                            FHA mortgage  11
# 12                    Federal student loan  12
# 13               Foreign currency exchange  13
# 14                    General purpose card  14
# 15                   Gift or merchant card  15
# 16         Government benefit payment card  16
# 17      Home equity loan or line of credit  17
# 18                         ID prepaid card  18
# 19                        Installment loan  19
# 20            International money transfer  20
# 21                                 Medical  21
# 22                           Mobile wallet  22
# 23                             Money order  23
# 24                                Mortgage  24
# 25                Non-federal student loan  25
# 26        Other (phone, health club, etc.)  26
# 27              Other bank product/service  27
# 28                          Other mortgage  28
# 29              Other special purpose card  29
# 30                               Pawn loan  30
# 31                             Payday loan  31
# 32                            Payroll card  32
# 33                 Personal line of credit  33
# 34               Refund anticipation check  34
# 35                        Reverse mortgage  35
# 36                         Savings account  36
# 37                              Title loan  37
# 38             Traveler's/Cashier's checks  38
# 39                Unknown or not specified  39
# 40                             VA mortgage  40
# 41                           Vehicle lease  41
# 42                            Vehicle loan  42

# %%
pd.set_option('display.max_rows', None)
pd.DataFrame({"Issue":Issue_enc.classes_, "ID":Issue_enc.transform(Issue_enc.classes_), }).head(90)
# Out:
#                                        Issue  ID
# 0                       APR or interest rate   0
# 1    Account opening, closing, or management   1
# 2                  Account terms and changes   2
# 3                               Adding money   3
# 4                  Advertising and marketing   4
# 5      Advertising, marketing or disclosures   5
# 6               Application processing delay   6
# 7   Application, originator, mortgage broker   7
# 8     Applied for loan/did not receive money   8
# 9                                Arbitration   9
# 10                          Balance transfer  10
# 11                      Balance transfer fee  11
# 12                                Bankruptcy  12
# 13                          Billing disputes  13
# 14                         Billing statement  14
# 15                      Can't contact lender  15
# 16                       Can't repay my loan  16
# 17        Can't stop charges to bank account  17
# 18                              Cash advance  18
# 19                          Cash advance fee  19
# 20        Charged bank acct wrong day or amt  20
# 21  Charged fees or interest I didn't expect  21
# 22                Closing/Cancelling account  22
# 23                     Communication tactics  23
# 24     Cont'd attempts collect debt not owed  24
# 25                        Convenience checks  25
# 26  Credit card protection / Debt protection  26
# 27            Credit decision / Underwriting  27
# 28                      Credit determination  28
# 29             Credit line increase/decrease  29
# 30  Credit monitoring or identity protection  30
# 31  Credit reporting company's investigation  31
# 32     Customer service / Customer relations  32
# 33       Customer service/Customer relations  33
# 34        Dealing with my lender or servicer  34
# 35                        Delinquent account  35
# 36                  Deposits and withdrawals  36
# 37           Disclosure verification of debt  37
# 38                               Disclosures  38
# 39                            Excessive fees  39
# 40        False statements or representation  40
# 41                                      Fees  41
# 42               Forbearance / Workout plans  42
# 43                             Fraud or scam  43
# 44                            Getting a loan  44
# 45     Identity theft / Fraud / Embezzlement  45
# 46       Improper contact or sharing of info  46
# 47          Improper use of my credit report  47
# 48                   Incorrect exchange rate  48
# 49    Incorrect information on credit report  49
# 50     Incorrect/missing disclosures or info  50
# 51                                  Late fee  51
# 52       Lender damaged or destroyed vehicle  52
# 53    Lender repossessed or sold the vehicle  53
# 54  Loan modification,collection,foreclosure  54
# 55  Loan servicing, payments, escrow account  55
# 56                      Lost or stolen check  56
# 57                Lost or stolen money order  57
# 58  Making/receiving payments, sending money  58
# 59               Managing the line of credit  59
# 60                Managing the loan or lease  60
# 61     Managing, opening, or closing account  61
# 62     Money was not available when promised  62
# 63                                     Other  63
# 64                                 Other fee  64
# 65                      Other service issues  65
# 66                  Other transaction issues  66
# 67    Overdraft, savings or rewards features  67
# 68                             Overlimit fee  68
# 69              Payment to acct not credited  69
# 70                            Payoff process  70
# 71                                   Privacy  71
# 72     Problems caused by my funds being low  72
# 73       Problems when you are unable to pay  73
# 74        Received a loan I didn't apply for  74
# 75                                   Rewards  75
# 76                           Sale of account  76
# 77              Settlement process and costs  77
# 78             Shopping for a line of credit  78
# 79              Shopping for a loan or lease  79
# 80              Taking out the loan or lease  80
# 81      Taking/threatening an illegal action  81
# 82                         Transaction issue  82
# 83  Unable to get credit report/credit score  83
# 84   Unauthorized transactions/trans. issues  84
# 85                     Unexpected/Other fees  85
# 86                  Unknown or not specified  86
# 87       Unsolicited issuance of credit card  87
# 88                 Using a debit or ATM card  88
# 89          Wrong amount charged or received  89

# %%
pd.DataFrame({"sub-issue":sub_Issue_enc.classes_, "ID":sub_Issue_enc.transform(sub_Issue_enc.classes_), })
# Out:
#                                    sub-issue  ID
# 0                             Account status   0
# 1                              Account terms   1
# 2                  Account terms and changes   2
# 3          Attempted to collect wrong amount   3
# 4        Attempted to/Collected exempt funds   4
# 5                            Billing dispute   5
# 6    Called after sent written cease of comm   6
# 7                  Called outside of 8am-9pm   7
# 8      Contacted employer after asked not to   8
# 9          Contacted me after I asked not to   9
# 10       Contacted me instead of my attorney  10
# 11                          Debt is not mine  11
# 12         Debt resulted from identity theft  12
# 13         Debt was discharged in bankruptcy  13
# 14                             Debt was paid  14
# 15                Frequent or repeated calls  15
# 16      Impersonated an attorney or official  16
# 17            Inadequate help over the phone  17
# 18      Indicated committed crime not paying  18
# 19    Indicated shouldn't respond to lawsuit  19
# 20                   Information is not mine  20
# 21               Investigation took too long  21
# 22  No notice of investigation status/result  22
# 23    Not disclosed as an attempt to collect  23
# 24      Not given enough info to verify debt  24
# 25                      Personal information  25
# 26     Problem cancelling or closing account  26
# 27     Problem getting my free annual report  27
# 28    Problem getting report or credit score  28
# 29                 Problem with fraud alerts  29
# 30         Problem with statement of dispute  30
# 31                             Public record  31
# 32  Received marketing offer after opted out  32
# 33  Receiving unwanted marketing/advertising  33
# 34        Reinserted previously deleted info  34
# 35           Report improperly shared by CRC  35
# 36   Report shared with employer w/o consent  36
# 37      Right to dispute notice not received  37
# 38        Seized/Attempted to seize property  38
# 39      Sued w/o proper notification of suit  39
# 40      Sued where didn't live/sign for debt  40
# 41     Talked to a third party about my debt  41
# 42      Threatened arrest/jail if do not pay  42
# 43         Threatened to sue on too old debt  43
# 44           Threatened to take legal action  44
# 45                  Unknown or not specified  45
# 46     Used obscene/profane/abusive language  46

# %%
pd.DataFrame({"Company response":Company_response_enc.classes_, "ID":Company_response_enc.transform(Company_response_enc.classes_), })
# Out:
#                   Company response  ID
# 0                           Closed   0
# 1          Closed with explanation   1
# 2      Closed with monetary relief   2
# 3  Closed with non-monetary relief   3
# 4                      In progress   4
# 5         Unknown or not specified   5
# 6                Untimely response   6
